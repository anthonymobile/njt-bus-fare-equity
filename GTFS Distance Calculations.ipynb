# %% [markdown]
# # Generate a Route Segment Length Table

# %%
import sys
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import gtfs_kit

# %%
# load the feed 
gtfs_path = 'data/bus_data.zip'
feed = gtfs_kit.read_feed(gtfs_path, dist_units='mi')

# %% [markdown]
# # functionized new algorithm

# %%
## function ##
#
# Generate stop list for a single route, including the longest trip in both directions
    
def make_route_distance_table(feed, gtfs_route_id, dates):
    
    # generate a timetable for this route
    timetable = gtfs_kit.routes.build_route_timetable(feed, gtfs_route_id, dates)
    
    results = []

    # loop to do both directions
    for direction_id, timetable_grouped_by_direction in timetable.groupby('direction_id'):
        
        # print(f"Direction {direction_id}")

        timetable_grouped_by_direction = timetable.groupby('direction_id')
        group_direction_0 = timetable_grouped_by_direction.get_group(direction_id)

        # Group by 'trip_id' within the selected group and calculate trip lengths
        result_group = group_direction_0.groupby('trip_id').size().reset_index(name='trip_length')

        # Perform aggregation to count occurrences and create a list of trip_ids
        aggregated_result = result_group.groupby('trip_length')['trip_id'].agg(['count', list]).reset_index()

        # pick a trip randomly from the list of trips that have the most stops for this direction
        max_count_row = aggregated_result[aggregated_result['count'] == aggregated_result['count'].max()]
        
        selected_value = np.random.choice(max_count_row['list'].iloc[0])

        # print(f"trip_id {selected_value}")
        
        # get timetable for that trip
        timetable_grouped_by_trip_id = timetable.groupby('trip_id')
        random_group = timetable_grouped_by_trip_id.get_group(selected_value)

        # lookup route_short_name in feed.routes and fill it down in the table
        condition = feed.routes['route_id'] == gtfs_route_id
        value_to_assign = feed.routes.loc[condition, 'route_short_name'].iloc[0]
        random_group.loc[:, 'route_short_name'] = value_to_assign

        # drop the trip_id
        random_group.drop('trip_id', axis=1, inplace=True)

        # Specify the desired order of columns
        desired_order = ['route_short_name','route_id','stop_id','stop_sequence','shape_dist_traveled']

        # Reorder columns
        results.append(random_group[desired_order])
        
        sys.stdout.write('.')
    
    # concatenate and return results
    
    return pd.concat(results, ignore_index=True)

# %% [markdown]
# ### main loop

# %%
## main loop ##
#
# Loop over routes and generate stop list with distances

# pick date
week = feed.get_first_week()
dates = [week[2]]  # First Wednesday

# create empty list to hold route by route results
dfs = []

# context to make things less annoying
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    # loop every every route in GTFS feed
    for index, row in feed.routes.iterrows():
        
        # print(f"Route {row['route_id']}" )

        # call function to generate list of stops with distances
        df = make_route_distance_table(feed, row['route_id'], dates)


        # append to results list
        dfs.append(df)

# create empty df and concatenate results
route_distance_table = pd.DataFrame()
route_distance_table=pd.concat(dfs, ignore_index=True)
route_distance_table
# Out:
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#       route_short_name route_id stop_id  stop_sequence  shape_dist_traveled
# 0                    1        1    2204              1               0.0000
# 1                    1        1   27662              2               0.1886
# 2                    1        1   27663              3               0.2991
# 3                    1        1   27664              4               0.4629
# 4                    1        1   27665              5               0.5725
# ...                ...      ...     ...            ...                  ...
# 25389             GO28      259   16176             17              11.3848
# 25390             GO28      259   40639             18              11.9958
# 25391             GO28      259   16184             19              12.4377
# 25392             GO28      259    1837             20              13.3799
# 25393             GO28      259    1836             21              13.9377
#
# [25394 rows x 5 columns]

# %% [markdown]
# # Add NJTransit Stop Codes

# %%
# # left — uses GTFS stop_id
# route_distance_table[route_distance_table["route_short_name"] == "119"]

# # right
# feed.stops

# %%
# join on stop_id
merged = pd \
    .merge(route_distance_table, feed.stops, on=['stop_id'], how='left') \
    .drop(['route_id','stop_desc','stop_lat','stop_lon','zone_id'], axis=1)
merged=merged.drop(['stop_id'], axis=1)
merged=merged.rename(columns={"stop_code" : "stop_id"})

# Save DataFrame to a pickle file
merged.to_pickle('data/njtransit_stop_distances.pkl')

# %%
# check one route
pd.set_option('display.max_rows', None)
display(merged[merged.route_short_name == '119'])
# Out:
#      route_short_name  stop_sequence  shape_dist_traveled stop_id  \
# 1323              119              1               0.0000   20383
# 1324              119              2               0.1242   20384
# 1325              119              3               0.3286   31594
# 1326              119              4               0.6252   20385
# 1327              119              5               0.7331   20386
# 1328              119              6               0.8284   20387
# 1329              119              7               0.9231   20388
# 1330              119              8               1.0473   20389
# 1331              119              9               1.1509   20390
# 1332              119             10               1.2383   20391
# 1333              119             11               1.3345   20392
# 1334              119             12               1.4492   20393
# 1335              119             13               1.7140   20394
# 1336              119             14               1.8718   20395
# 1337              119             15               2.0174   20396
# 1338              119             16               2.2080   20397
# 1339              119             17               2.4006   30400
# 1340              119             18               2.4665   20398
# 1341              119             19               2.5483   20399
# 1342              119             20               2.7004   31455
# 1343              119             21               2.8917   20400
# 1344              119             22               3.0072   20401
# 1345              119             23               3.1242   20402
# 1346              119             24               3.2208   20403
# 1347              119             25               3.3384   20404
# 1348              119             26               3.3964   20405
# 1349              119             27               3.5634   20406
# 1350              119             28               3.6795   20790
# 1351              119             29               3.8212   20791
# 1352              119             30               3.9581   31756
# 1353              119             31               4.0407   20792
# 1354              119             32               4.1333   20793
# 1355              119             33               4.2405   20794
# 1356              119             34               4.3826   20795
# 1357              119             35               4.4828   20796
# 1358              119             36               4.5956   20797
# 1359              119             37               4.7032   20799
# 1360              119             38               4.8161   20800
# 1361              119             39               4.9064   20801
# 1362              119             40               5.0241   31591
# 1363              119             41               5.1610   20802
# 1364              119             42               5.2333   20803
# 1365              119             43               5.3504   20804
# 1366              119             44               5.4195   20805
# 1367              119             45               5.5375   20806
# 1368              119             46               5.6987   20807
# 1369              119             47               5.8081   20808
# 1370              119             48               5.9080   20809
# 1371              119             49               5.9617   20810
# 1372              119             50               6.1218   20811
# 1373              119             51               6.1741   20812
# 1374              119             52               6.2972   20813
# 1375              119             53               6.4470   20814
# 1376              119             54               6.5242   20815
# 1377              119             55               6.6583   20816
# 1378              119             56               6.8203   20817
# 1379              119             57               6.8682   21092
# 1380              119             58               7.2169   31732
# 1381              119             59               7.2345   31731
# 1382              119             60               7.6212   20783
# 1383              119             61               7.7394   20610
# 1384              119             62               7.8436   20611
# 1385              119             63               7.9320   20612
# 1386              119             64               8.0809   20613
# 1387              119             65               8.1979   20614
# 1388              119             66               8.2439   30227
# 1389              119             67               8.3417   20615
# 1390              119             68               8.3998   31102
# 1391              119             69               8.5070   20616
# 1392              119             70               8.6076   20617
# 1393              119             71               8.6975   20618
# 1394              119             72               8.8523   20620
# 1395              119             73               8.9820   20621
# 1396              119             74               9.0701   20666
# 1397              119             75               9.1631   30189
# 1398              119             76               9.2720   31211
# 1399              119             77               9.3697   21079
# 1400              119             78               9.5886   31198
# 1401              119             79              10.2644   32084
# 1402              119             80              10.5953   21853
# 1403              119             81              13.1208   31899
# 1404              119             82              13.2945   31858
# 1405              119              1               0.0000   26229
# 1406              119              2               2.6515   21854
# 1407              119              3               3.0059   20523
# 1408              119              4               4.0117   20668
# 1409              119              5               4.1002   20670
# 1410              119              6               4.2138   20671
# 1411              119              7               4.3019   20672
# 1412              119              8               4.4316   20629
# 1413              119              9               4.5691   20631
# 1414              119             10               4.6909   20632
# 1415              119             11               4.8409   20634
# 1416              119             12               4.9422   20635
# 1417              119             13               5.0246   20636
# 1418              119             14               5.0860   20637
# 1419              119             15               5.2030   20638
# 1420              119             16               5.3002   20639
# 1421              119             17               5.3519   20640
# 1422              119             18               5.4403   20641
# 1423              119             19               5.5623   20642
# 1424              119             20               5.6898   20784
# 1425              119             21               5.8468   21124
# 1426              119             22               6.2267   31732
# 1427              119             23               6.2443   31731
# 1428              119             24               6.7011   21093
# 1429              119             25               6.7699   20852
# 1430              119             26               6.9087   20853
# 1431              119             27               6.9782   20854
# 1432              119             28               7.1063   20855
# 1433              119             29               7.2786   20856
# 1434              119             30               7.4277   20858
# 1435              119             31               7.5013   20859
# 1436              119             32               7.5992   20860
# 1437              119             33               7.7443   20861
# 1438              119             34               7.8023   20862
# 1439              119             35               7.9081   20863
# 1440              119             36               8.0515   20864
# 1441              119             37               8.1583   20865
# 1442              119             38               8.2331   20866
# 1443              119             39               8.3241   20867
# 1444              119             40               8.4294   20868
# 1445              119             41               8.5674   31592
# 1446              119             42               8.6729   20869
# 1447              119             43               8.7280   20870
# 1448              119             44               8.7682   20871
# 1449              119             45               8.8989   20872
# 1450              119             46               8.9547   20873
# 1451              119             47               9.0756   20875
# 1452              119             48               9.1867   20876
# 1453              119             49               9.3472   20877
# 1454              119             50               9.4460   20878
# 1455              119             51               9.5182   20879
# 1456              119             52               9.6112   20880
# 1457              119             53               9.7968   20881
# 1458              119             54               9.8956   20882
# 1459              119             55              10.0047   20407
# 1460              119             56              10.2509   20409
# 1461              119             57              10.3991   20410
# 1462              119             58              10.4657   20411
# 1463              119             59              10.6475   20412
# 1464              119             60              10.7617   20413
# 1465              119             61              10.8477   20414
# 1466              119             62              10.9572   20415
# 1467              119             63              11.0379   20416
# 1468              119             64              11.1691   20417
# 1469              119             65              11.3087   20418
# 1470              119             66              11.4564   20419
# 1471              119             67              11.6981   20420
# 1472              119             68              11.8559   20421
# 1473              119             69              11.9883   20422
# 1474              119             70              12.1206   20423
# 1475              119             71              12.3589   20424
# 1476              119             72              12.5225   20425
# 1477              119             73              12.7337   20426
# 1478              119             74              12.8366   20427
# 1479              119             75              12.9445   20428
# 1480              119             76              13.2799   31595
# 1481              119             77              13.4362   31596
# 1482              119             78              13.6670   20430
#
#                                         stop_name
# 1323                           JFK BLVD AT 3RD ST
# 1324                           JFK BLVD AT 4TH ST
# 1325                     JFK BLVD AT W 7TH STREET
# 1326                           JFK BLVD AT 8TH ST
# 1327                          JFK BLVD AT 10TH ST
# 1328                          JFK BLVD AT 12TH ST
# 1329                          JFK BLVD AT 14TH ST
# 1330                          JFK BLVD AT 16TH ST
# 1331                        JFK BLVD AT ANDREW ST
# 1332                          JFK BLVD AT 19TH ST
# 1333                          JFK BLVD AT 21ST ST
# 1334                          JFK BLVD AT 23RD ST
# 1335                          JFK BLVD AT 27TH ST
# 1336                          JFK BLVD AT 30TH ST
# 1337                          JFK BLVD AT 32ND ST
# 1338                          JFK BLVD AT 34TH ST
# 1339                         JFK BLVD AT 38 TH ST
# 1340                          JFK BLVD AT 39TH ST
# 1341                        JFK BLVD AT DELVIN DR
# 1342                        JFK BLVD AT W 44TH ST
# 1343                          JFK BLVD AT 48TH ST
# 1344                          JFK BLVD AT 50TH ST
# 1345                          JFK BLVD AT 52ND ST
# 1346                          JFK BLVD AT 54TH ST
# 1347                          JFK BLVD AT 57TH ST
# 1348                          JFK BLVD AT 58TH ST
# 1349                          JFK BLVD AT 63RD ST
# 1350                      JFK BLVD AT PAMRAPO AVE
# 1351                        JFK BLVD AT GATES AVE
# 1352                     JFK BLVD AT WINFIELD AVE
# 1353                     JFK BLVD AT PEARSALL AVE
# 1354                   JFK BLVD AT GREENVILLE AVE
# 1355                     JFK BLVD AT DANFORTH AVE
# 1356                       JFK BLVD AT MCADOO AVE
# 1357                          JFK BLVD AT WADE ST
# 1358                       JFK BLVD AT FOWLER AVE
# 1359                     JFK BLVD AT WOODLAWN AVE
# 1360                        JFK BLVD AT DWIGHT ST
# 1361                      JFK BLVD AT AUDUBON AVE
# 1362              JFK BLVD 50'N OF BAYVIEW AVENUE
# 1363                    JFK BLVD AT BROADMAN PKWY
# 1364                    JFK BLVD AT CLAREMONT AVE
# 1365                        JFK BLVD AT MORTON PL
# 1366                          JFK BLVD AT EGE AVE
# 1367                         JFK BLVD AT BOYD AVE
# 1368                    JFK BLVD AT CLENDENNY AVE
# 1369                      JFK BLVD AT CLINTON AVE
# 1370                   JFK BLVD AT COMMUNIPAW AVE
# 1371                      JFK BLVD AT BENTLEY AVE
# 1372                   JFK BLVD AT KENSINGTON AVE
# 1373                       JFK BLVD AT JEWETT AVE
# 1374                       JFK BLVD AT DUNCAN AVE
# 1375                    JFK BLVD AT MONTGOMERY ST
# 1376                     JFK BLVD AT GLENWOOD AVE
# 1377                   JFK BLVD AT STUYVESANT AVE
# 1378                          JFK BLVD AT SIP AVE
# 1379                      SIP AVE AT TONNELLE AVE
# 1380         JOURNAL SQUARE TRANSPORTATION CENTER
# 1381         JOURNAL SQUARE TRANSPORTATION CENTER
# 1382                    HOBOKEN AVE AT SUMMIT AVE
# 1383                   CENTRAL AVE AT HOBOKEN AVE
# 1384               CENTRAL AVE AT SAINT PAULS AVE
# 1385                    CENTRAL AVE AT BEACON AVE
# 1386                    CENTRAL AVE AT WAVERLY ST
# 1387                 CENTRAL AVE AT RESERVOIR AVE
# 1388                   CENTRAL AVE AT BOORAEM AVE
# 1389                 CENTRAL AVE AT MANHATTAN AVE
# 1390                   CENTRAL AVE AT FRANKLIN ST
# 1391                     CENTRAL AVE AT HUTTON ST
# 1392                   CENTRAL AVE AT GRIFFITH ST
# 1393                     CENTRAL AVE AT BOWERS ST
# 1394                      CENTRAL AVE AT SOUTH ST
# 1395                   CENTRAL AVE AT CONGRESS ST
# 1396                   CONGRESS ST AT HANCOCK AVE
# 1397                   CONGRESS ST AT WEBSTER AVE
# 1398                  CONGRESS ST AT PALISADE AVE
# 1399             PATERSON PLANK RD AT CONGRESS ST
# 1400  S WING VIADUCT 180'N OF PATERSON PLANK ROAD
# 1401                        WILLOW AVE AT 15TH ST
# 1402                        WILLOW AVE AT 19TH ST
# 1403                      PORT AUTHORITY DROP OFF
# 1404                  PORT AUTHORITY BUS TERMINAL
# 1405                  PORT AUTHORITY BUS TERMINAL
# 1406                        WILLOW AVE AT 19TH ST
# 1407                        WILLOW AVE AT 15TH ST
# 1408                  CONGRESS ST AT PALISADE AVE
# 1409                   CONGRESS ST AT WEBSTER AVE
# 1410                   CONGRESS ST AT HANCOCK AVE
# 1411                   CONGRESS ST AT CENTRAL AVE
# 1412                      CENTRAL AVE AT SOUTH ST
# 1413                     CENTRAL AVE AT BOWERS ST
# 1414                   CENTRAL AVE AT GRIFFITH ST
# 1415                    CENTRAL AVE AT SHERMAN PL
# 1416                 CENTRAL AVE AT MANHATTAN AVE
# 1417                   CENTRAL AVE AT BOOREAM AVE
# 1418                CENTRAL AVE AT PERSHING PLAZA
# 1419                    CENTRAL AVE AT WAVERLY ST
# 1420                   CENTRAL AVE AT LAIDLAW AVE
# 1421                    CENTRAL AVE AT BEACON AVE
# 1422               CENTRAL AVE AT SAINT PAULS AVE
# 1423                   CENTRAL AVE AT HOBOKEN AVE
# 1424                    HOBOKEN AVE AT SUMMIT AVE
# 1425                    SUMMIT AVE AT PAVONIA AVE
# 1426         JOURNAL SQUARE TRANSPORTATION CENTER
# 1427         JOURNAL SQUARE TRANSPORTATION CENTER
# 1428                      SIP AVE AT TONNELLE AVE
# 1429                          JFK BLVD AT SIP AVE
# 1430                   JFK BLVD AT STUYVESANT AVE
# 1431                     JFK BLVD AT HIGHLAND AVE
# 1432                    JFK BLVD AT MONTGOMERY ST
# 1433                       JFK BLVD AT DUNCAN AVE
# 1434                   JFK BLVD AT KENSINGTON AVE
# 1435                   JFK BLVD AT BELMONT AVENUE
# 1436                      JFK BLVD AT BENTLEY AVE
# 1437                   JFK BLVD AT COMMUNIPAW AVE
# 1438                       JFK BLVD AT OXFORD AVE
# 1439                    JFK BLVD AT CLENDENNY AVE
# 1440                         JFK BLVD AT BOYD AVE
# 1441                          JFK BLVD AT EGE AVE
# 1442                        JFK BLVD AT MORTON PL
# 1443                    JFK BLVD AT CLAREMONT AVE
# 1444                    JFK BLVD AT BROADMAN PKWY
# 1445                      JFK BLVD AT BAYVIEW AVE
# 1446                      JFK BLVD AT AUDUBON AVE
# 1447                     JFK BLVD AT STEGMAN PKWY
# 1448                   JFK BLVD AT VAN HOUTEN AVE
# 1449                     JFK BLVD AT WOODLAWN AVE
# 1450                 JFK BLVD AT VAN NOSTRAND AVE
# 1451                      JFK BLVD AT STEVENS AVE
# 1452                       JFK BLVD AT MCADOO AVE
# 1453                     JFK BLVD AT DANFORTH AVE
# 1454                   JFK BLVD AT GREENVILLE AVE
# 1455                     JFK BLVD AT PEARSALL AVE
# 1456                     JFK BLVD AT WINFIELD AVE
# 1457                        JFK BLVD AT GATES AVE
# 1458                      JFK BLVD AT PAMRAPO AVE
# 1459                          JFK BLVD AT 63RD ST
# 1460                          JFK BLVD AT 57TH ST
# 1461                          JFK BLVD AT 54TH ST
# 1462                          JFK BLVD AT 52ND ST
# 1463                          JFK BLVD AT 48TH ST
# 1464                          JFK BLVD AT 46TH ST
# 1465                          JFK BLVD AT 44TH ST
# 1466                          JFK BLVD AT 42ND ST
# 1467                        JFK BLVD AT DILLON DR
# 1468                          JFK BLVD AT 37TH ST
# 1469                          JFK BLVD AT 35TH ST
# 1470                          JFK BLVD AT 33RD ST
# 1471                          JFK BLVD AT 30TH ST
# 1472                          JFK BLVD AT 27TH ST
# 1473                        JFK BLVD AT W 25TH ST
# 1474                          JFK BLVD AT 23RD ST
# 1475                          JFK BLVD AT 19TH ST
# 1476                          JFK BLVD AT 16TH ST
# 1477                          JFK BLVD AT 12TH ST
# 1478                          JFK BLVD AT 10TH ST
# 1479                           JFK BLVD AT 8TH ST
# 1480                     JFK BLVD AT W 6TH STREET
# 1481                     JFK BLVD AT W 4TH STREET
# 1482                           JFK BLVD AT 2ND ST
